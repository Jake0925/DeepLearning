# %% [markdown]
# <a href="https://colab.research.google.com/github/Jake0925/DeepLearning/blob/master/Seaborn_scatter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")



# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="carat", y="price",
                hue="clarity", size="depth",
                palette="ch:r=-.2,d=.3_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=diamonds, ax=ax)

# %%
diamonds = sns.load_dataset("diamonds")
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
plt.figure(figsize=(10,6.5))
sns.scatterplot(data=diamonds, x='carat', y='price', hue="clarity")

# %%
plt.figure(figsize=(10,6.5))
sns.scatterplot(data=diamonds, x='carat', y='price', hue="clarity", hue_order=clarity_ranking)

# %%
plt.figure(figsize=(10,6.5))
sns.scatterplot(data=diamonds, x='carat', y='price', hue="clarity", hue_order=clarity_ranking, size='depth') # depth에 따라 point의 크기가 달라진다

# %%
plt.figure(figsize=(10,6.5))
sns.scatterplot(data=diamonds, x='carat', y='price', hue="clarity", hue_order=clarity_ranking, 
                size='depth', sizes=(1, 8), linewidth=0,) # depth에 따라 point의 크기가 달라지는데 sizes를 통해 1~8범위내의 크기로 변경된다

# %%
plt.figure(figsize=(10,6.5))
sns.scatterplot(data=diamonds, x='carat', y='price', hue="clarity", hue_order=clarity_ranking,palette="ch:r=-.2,d=.3_r",)

# %%
f, ax = plt.subplots(figsize=(10, 6.5))
sns.despine(f, left=True, bottom=True) # Gird의 좌측과 하단의 좁은 경계를 없애준다
sns.scatterplot(data=diamonds, x='carat', y='price', hue="clarity", hue_order=clarity_ranking,palette="ch:r=-.2,d=.3_r",)
