# %% [markdown]
# <a href="https://colab.research.google.com/github/Jake0925/DeepLearning/blob/master/5_%EB%A1%9C%EC%A7%80%EC%8A%A4%ED%8B%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/hunkim/DeepLearningZeroToAll/blob/master/tf2/tf2-05-1-logistic_regression.py

# %%
import tensorflow as tf

# %%
x_data = [[1, 2],
          [2, 3],
          [3, 1],
          [4, 3],
          [5, 3],
          [6, 2]]

# 0은 불합격, 1은 합격
y_data = [[0],
          [0],
          [0],
          [1],
          [1],
          [1]]

# %% [markdown]
# # Sigmoid
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=2))

# use sigmoid activation for 0~1 problem
tf.model.add(tf.keras.layers.Activation('sigmoid'))

# %% [markdown]
# # Cost
#
#
# ![image.png](data:image/png;base64,...)

# %%
'''
better result with loss function == 'binary_crossentropy', try 'mse' for yourself
adding accuracy metric to get accuracy report during training
'''
tf.model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.SGD(lr=0.01), metrics=['accuracy'])
tf.model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 3
#
#  activation (Activation)     (None, 1)                 0
#
# ...
# Total params: 3 (12.00 Byte)
# Trainable params: 3 (12.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = tf.model.fit(x_data, y_data, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.5490 - accuracy: 0.8333
# Epoch 2/1000
# 1/1 [==============================] - 0s 18ms/step - loss: 0.5487 - accuracy: 0.8333
# Epoch 3/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5484 - accuracy: 0.8333
# Epoch 4/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5481 - accuracy: 0.8333
# Epoch 5/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5478 - accuracy: 0.8333
# Epoch 6/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5475 - accuracy: 0.8333
# Epoch 7/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5473 - accuracy: 0.8333
# Epoch 8/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5470 - accuracy: 0.8333
# Epoch 9/1000
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5467 - accuracy: 0.8333
# Epoch 10/1000
# ...

# %%
print("Accuracy: ", history.history['accuracy'][-1])
# Out:
# Accuracy:  0.8333333134651184
