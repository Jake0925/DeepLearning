# %% [markdown]
# <a href="https://colab.research.google.com/github/Jake0925/DeepLearning/blob/master/Seaborn_%EC%8B%9C%EA%B3%84%EC%97%B4%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%8B%9C%EA%B0%81%ED%99%94_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df=sns.load_dataset('flights')
print(df.shape)
df.head()
# Out:
# (144, 3)
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %% [markdown]
# Barplot

# %%
plt.figure(figsize=(10,4))
sns.barplot(data=df, x='year', y='passengers') #각 그래프의 검정색 수직방향 선은 신뢰구간을 나타낸다

# %% [markdown]
# Lineplot

# %%
plt.figure(figsize=(10,4))
sns.lineplot(data=df, x='year', y='passengers')

# %% [markdown]
# pointplot

# %%
plt.figure(figsize=(10,4))
sns.pointplot(data=df, x='year', y='passengers')

# %% [markdown]
# 각 연별로 월별 데이터표시

# %%
plt.figure(figsize=(15,4))
sns.barplot(data=df, x='year', y='passengers', hue='month')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.) # 범례박스를 그래프 밖으로 이동시킴

# %%
plt.figure(figsize=(15,4))
sns.lineplot(data=df, x='year', y='passengers', hue='month')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(15,4))
sns.lineplot(data=df, x='month', y='passengers', hue='year')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# Boxplot

# %%
plt.figure(figsize=(15,4))
sns.boxplot(data=df, x = 'year', y='passengers')

# %%
plt.figure(figsize=(15,4))
sns.boxenplot(data=df, x = 'year', y='passengers')

# %%
plt.figure(figsize=(15,4))
sns.swarmplot(data=df, x = 'year', y='passengers')
sns.violinplot(data=df, x = 'year', y='passengers', color='blue')

# %%
plt.figure(figsize=(15,4))
sns.regplot(data=df, x = 'year', y='passengers')
