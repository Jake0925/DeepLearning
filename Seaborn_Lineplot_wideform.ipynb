# %% [markdown]
# <a href="https://colab.research.google.com/github/Jake0925/DeepLearning/blob/master/Seaborn_Lineplot_wideform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
sns.set_theme(style="whitegrid")
rs = np.random.RandomState(365)

values = rs.randn(365, 4).cumsum(axis=0)
dates = pd.date_range("1 1 2016", periods=365, freq="D")
data = pd.DataFrame(values, dates, columns=["A", "B", "C", "D"])
data = data.rolling(7).mean()

sns.lineplot(data=data, palette="tab10", linewidth=2.5)

# %%
values = rs.randn(365, 4).cumsum(axis=0)
pd.DataFrame(values)
# Out:
#              0          1          2          3
# 0    -2.141599  -1.238566   1.392947   0.539502
# 1    -1.762745  -1.452897   0.743455  -2.071589
# 2     0.726889  -1.243068   0.329879  -3.030949
# 3     1.375003  -0.168575   1.532667  -2.428280
# 4    -0.600250  -0.402924   0.781410  -2.825544
# ..         ...        ...        ...        ...
# 360  40.713492  16.066131 -14.218985   8.632282
# 361  41.346311  16.296816 -13.393641   9.679975
# 362  40.782793  14.961541 -12.913813  10.503607
# 363  41.073768  13.959027 -12.037989  10.908476
# 364  40.185918  13.869666 -13.446943  10.717045
#
# [365 rows x 4 columns]

# %%
data = pd.DataFrame(values, dates, columns=['A', 'B', 'C', 'D']) # columns 이름 변경
print(data.head(1))
print(data.tail(1))
# Out:
#                    A         B         C         D
# 2021-01-01 -2.141599 -1.238566  1.392947  0.539502
#                     A          B          C          D
# 2021-12-31  40.185918  13.869666 -13.446943  10.717045

# %%
data = data.rolling(7).mean() # 7간격으로 이동평균값을 찍는다

# %%
dates = pd.date_range("1 1 2021", periods=365, freq="D")
dates
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-09', '2021-01-10',
#                ...
#                '2021-12-22', '2021-12-23', '2021-12-24', '2021-12-25',
#                '2021-12-26', '2021-12-27', '2021-12-28', '2021-12-29',
#                '2021-12-30', '2021-12-31'],
#               dtype='datetime64[ns]', length=365, freq='D')

# %%
sns.lineplot(data=data)

# %%
sns.lineplot(data=data, palette='tab10', linewidth=10)
