# %% [markdown]
# <a href="https://colab.research.google.com/github/Jake0925/DeepLearning/blob/master/Seaborn_catplot_%EB%B6%84%EC%82%B0%EB%B6%84%ED%8F%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

penguins = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=penguins, kind="bar",
    x="species", y="body_mass_g", hue="sex",
    ci="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Body mass (g)")
g.legend.set_title("")

# %%
df = sns.load_dataset("exercise")
print(df.shape)
df.head()
# Out:
# (90, 6)
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
df.kind.value_counts() # kind항목은 결과종류별로 몇개씩 있는지 확인가능
# Out:
# running    30
# walking    30
# rest       30
# Name: kind, dtype: int64

# %%
sns.pointplot(data=df, x='time', y = 'pulse', hue='kind',
              capsize=.2)

# %%
sns.pointplot(data=df, x='time', y = 'pulse', hue='kind',
              capsize=.2) # 수직선은 초기값으로 신뢰구간 95%로 설정되어있는것을 나타낸다
sns.pointplot(data=df, x='time', y = 'pulse', hue='kind',
              capsize=.1,
              ci='sd') # 표준편차

# %%
sns.catplot(data=df, x='time', y = 'pulse')

# %%
sns.catplot(data=df, x='time', y = 'pulse', kind='point')

# %%
sns.catplot(data=df, x='time', y = 'pulse', kind='bar')

# %%
sns.catplot(data=df, x='time', y = 'pulse', kind='violin')

# %%
sns.catplot(data=df, x='time', y = 'pulse', hue='kind', kind='point', capsize=.2,
            col='diet')
