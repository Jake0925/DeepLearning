# %% [markdown]
# <a href="https://colab.research.google.com/github/Jake0925/DeepLearning/blob/master/9_%EC%8B%A0%EA%B2%BD%EB%A7%9D(Neural_Network).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ref
#
# https://www.youtube.com/watch?v=oFGHOsAYiz0
#
# https://github.com/hunkim/DeepLearningZeroToAll/blob/master/tf2/tf2-09-2-xor-nn.py

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Lab 9 XOR
import tensorflow as tf
import numpy as np

x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)

tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=2, activation='sigmoid'))
tf.model.compile(loss='binary_crossentropy', optimizer=tf.optimizers.SGD(lr=0.01),  metrics=['accuracy'])
tf.model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 3
#
# ...
# Total params: 3 (12.00 Byte)
# Trainable params: 3 (12.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/1000
# 1/1 [==============================] - 1s 961ms/step - loss: 0.7321 - accuracy: 0.5000
# Epoch 2/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7319 - accuracy: 0.2500
# Epoch 3/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7316 - accuracy: 0.2500
# Epoch 4/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7314 - accuracy: 0.2500
# Epoch 5/1000
# ...

# %%
history = tf.model.fit(x_data, y_data, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 0.6959 - accuracy: 0.5000
# Epoch 2/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6959 - accuracy: 0.5000
# Epoch 3/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6959 - accuracy: 0.5000
# Epoch 4/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6959 - accuracy: 0.5000
# Epoch 5/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.6959 - accuracy: 0.5000
# Epoch 6/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6959 - accuracy: 0.5000
# Epoch 7/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6959 - accuracy: 0.5000
# Epoch 8/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6959 - accuracy: 0.5000
# Epoch 9/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6959 - accuracy: 0.5000
# Epoch 10/1000
# ...

# %%
predictions = tf.model.predict(x_data)
print('Prediction: \n', predictions)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# Prediction:
#  [[0.5357688 ]
#  [0.49207306]
#  [0.51909477]
#  [0.47536644]]

# %%
# 정확도가 0.5로서 생각보다 매우 낮다
score = tf.model.evaluate(x_data, y_data)
print('Accuracy: ', score[1])
# Out:
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6943 - accuracy: 0.5000
# Accuracy:  0.5

# %% [markdown]
# # 9-2
# 이를 개선하기 위해 여러개의 layer를 사용한다
#
# ![image.png](data:image/png;base64,...)

# %%
# Lab 9 XOR
import tensorflow as tf
import numpy as np

x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)

tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=2, input_dim=2)) # layer1
tf.model.add(tf.keras.layers.Activation('sigmoid'))
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=2)) # layer2 - layer1의 출력갯수와 layer2의 입력개수는 동일해야한다
tf.model.add(tf.keras.layers.Activation('sigmoid'))
tf.model.compile(loss='binary_crossentropy', optimizer=tf.optimizers.SGD(lr=0.1),  metrics=['accuracy'])
tf.model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_5 (Dense)             (None, 2)                 6
#
#  activation_4 (Activation)   (None, 2)                 0
#
#  dense_6 (Dense)             (None, 1)                 3
#
#  activation_5 (Activation)   (None, 1)                 0
#
# ...
# Total params: 9 (36.00 Byte)
# Trainable params: 9 (36.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = tf.model.fit(x_data, y_data, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 1s 688ms/step - loss: 0.7070 - accuracy: 0.5000
# Epoch 2/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.7069 - accuracy: 0.5000
# Epoch 3/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7069 - accuracy: 0.5000
# Epoch 4/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7068 - accuracy: 0.5000
# Epoch 5/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7067 - accuracy: 0.5000
# Epoch 6/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7066 - accuracy: 0.5000
# Epoch 7/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7065 - accuracy: 0.5000
# Epoch 8/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7064 - accuracy: 0.5000
# Epoch 9/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7064 - accuracy: 0.5000
# Epoch 10/1000
# ...

# %%
predictions = tf.model.predict(x_data)
print('Prediction: \n', predictions)
# Out:
# 1/1 [==============================] - 0s 119ms/step
# Prediction:
#  [[0.4905492 ]
#  [0.524334  ]
#  [0.48520902]
#  [0.51114863]]

# %%
score = tf.model.evaluate(x_data, y_data)
print('Accuracy: ', score[1])
# Out:
# 1/1 [==============================] - 0s 185ms/step - loss: 0.6897 - accuracy: 0.5000
# Accuracy:  0.5

# %% [markdown]
# 9-2
#
# layer1의 출력값을 wide하게 즉 여러개가 되도록 설정
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 9-3
#
# - 깊게 신경망을 생성하는 경우
#
# - layer와 출력을 wide하게 하는것이다
#
#
# ![image.png](data:image/png;base64,...)

# %%
# Lab 9 XOR
# 9-3 deep and wide
import tensorflow as tf
import numpy as np

x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)

tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=10, input_dim=2, activation='sigmoid')) # layer1, 출력개수는 원하는데로 설정하고 여러개를 설정하였으므로 wide하다
tf.model.add(tf.keras.layers.Dense(units=10, activation='sigmoid')) # layer, layer1의 출력갯수와 layer2의 입력개수는 동일해야한다
tf.model.add(tf.keras.layers.Dense(units=10, activation='sigmoid')) # layer3
tf.model.add(tf.keras.layers.Dense(units=10, activation='sigmoid')) # layer4
tf.model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))  # layer5 층이 여러개 이이므로 신경망이 깊다고 할수있다

# SGD not working very well due to vanishing gradient problem, switched to Adam for now
# or you may use activation='relu', study chapter 10 to know more on vanishing gradient problem.
tf.model.compile(loss='binary_crossentropy', optimizer=tf.optimizers.Adam(lr=0.1), metrics=['accuracy'])
tf.model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 10)                30
#
#  dense_8 (Dense)             (None, 10)                110
#
#  dense_9 (Dense)             (None, 10)                110
#
#  dense_10 (Dense)            (None, 10)                110
#
#  dense_11 (Dense)            (None, 1)                 11
#
# ...
# Total params: 371 (1.45 KB)
# Trainable params: 371 (1.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = tf.model.fit(x_data, y_data, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 1s 1s/step - loss: 0.7589 - accuracy: 0.5000
# Epoch 2/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7568 - accuracy: 0.5000
# Epoch 3/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7547 - accuracy: 0.5000
# Epoch 4/1000
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7527 - accuracy: 0.5000
# Epoch 5/1000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7507 - accuracy: 0.5000
# Epoch 6/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7487 - accuracy: 0.5000
# Epoch 7/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7468 - accuracy: 0.5000
# Epoch 8/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7449 - accuracy: 0.5000
# Epoch 9/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7430 - accuracy: 0.5000
# Epoch 10/1000
# ...

# %%
predictions = tf.model.predict(x_data)
print('Prediction: \n', predictions)

# 매우 정확해짐
score = tf.model.evaluate(x_data, y_data)
print('Accuracy: ', score[1])
# Out:
# 1/1 [==============================] - 0s 178ms/step
# Prediction:
#  [[0.30295548]
#  [0.5668698 ]
#  [0.71411103]
#  [0.45741203]]
# 1/1 [==============================] - 0s 251ms/step - loss: 0.4692 - accuracy: 1.0000
# Accuracy:  1.0

# %% [markdown]
# # TensorBord

# %%
# Lab 9 XOR
import datetime
import numpy as np
import os
import tensorflow as tf

x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)

tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=2, input_dim=2))
tf.model.add(tf.keras.layers.Activation('sigmoid'))
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=2))
tf.model.add(tf.keras.layers.Activation('sigmoid'))
tf.model.compile(loss='binary_crossentropy', optimizer=tf.optimizers.SGD(lr=0.1),  metrics=['accuracy'])
tf.model.summary()

# prepare callback
log_dir = os.path.join(".", "logs", "fit", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# add callback param to fit()
history = tf.model.fit(x_data, y_data, epochs=1000, callbacks=[tensorboard_callback])

predictions = tf.model.predict(x_data)
print('Prediction: \n', predictions)

score = tf.model.evaluate(x_data, y_data)
print('Accuracy: ', score[1])

'''
at the end of the run, open terminal / command window
cd to the source directory
tensorboard --logdir logs/fit

read more on tensorboard: https://www.tensorflow.org/tensorboard/get_started
'''
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 2)                 6
#
#  activation_6 (Activation)   (None, 2)                 0
#
#  dense_13 (Dense)            (None, 1)                 3
#
#  activation_7 (Activation)   (None, 1)                 0
#
# ...
# Total params: 9 (36.00 Byte)
# Trainable params: 9 (36.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/1000
# 1/1 [==============================] - 1s 664ms/step - loss: 0.8057 - accuracy: 0.5000
# Epoch 2/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 0.8049 - accuracy: 0.5000
# Epoch 3/1000
# ...
